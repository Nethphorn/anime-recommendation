# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

anime_df = pd.read_csv('data/AnimeList/AnimeList.csv')
# print(anime_df.head()) #first 5 rows
# print(anime_df.shape) #how many rows/columns
# print(anime_df.info()) #data types
# print(anime_df.describe()) #statistics summary

print(anime_df.isnull().sum())
# Out:
# anime_id              0
# title                 0
# title_english      8754
# title_japanese       35
# title_synonyms     5541
# image_url            96
# type                  0
# source                0
# episodes              0
# status                0
# airing                0
# aired_string          0
# aired                 0
# duration              0
# rating              544
# score                 0
# scored_by             0
# rank               1574
# popularity            0
# members               0
# favorites             0
# background        13421
# premiered         10382
# broadcast         10207
# related               0
# producer           6190
# licensor          11105
# studio             5934
# genre                64
# opening_theme         0
# ending_theme          0
# dtype: int64

# %%
anime_df
# Out:
#        anime_id                                  title  \
# 0         11013                          Inu x Boku SS
# 1          2104                       Seto no Hanayome
# 2          5262                     Shugo Chara!! Doki
# 3           721                          Princess Tutu
# 4         12365                    Bakuman. 3rd Season
# ...         ...                                    ...
# 14473     26089             Gutchonpa Omoshiro Hanashi
# 14474     21525                   Geba Geba Shou Time!
# 14475     37897            Godzilla: Hoshi wo Kuu Mono
# 14476     34193  Nippon Mukashibanashi: Sannen Netarou
# 14477     37908             Senjou no Valkyria Special
#
#                    title_english                  title_japanese  \
# 0      Inu X Boku Secret Service                          妖狐×僕SS
# 1          My Bride is a Mermaid                           瀬戸の花嫁
# 2             Shugo Chara!! Doki                     しゅごキャラ！！どきっ
# ...

# %%
user_df = pd.read_csv('data/AnimeList/UserAnimeList.csv')

# %%
user_df
# Out:
#             username  anime_id  my_watched_episodes my_start_date  \
# 0           karthiga        21                  586    0000-00-00
# 1           karthiga        59                   26    0000-00-00
# 2           karthiga        74                   26    0000-00-00
# 3           karthiga       120                   26    0000-00-00
# 4           karthiga       178                   26    0000-00-00
# ...              ...       ...                  ...           ...
# 80076107  mini_kaila      5940                    4    0000-00-00
# 80076108  mini_kaila      6030                    0    0000-00-00
# 80076109  mini_kaila      6500                    1    0000-00-00
# 80076110  mini_kaila      7058                    0    0000-00-00
# 80076111  mini_kaila      7088                    1    0000-00-00
#
#          my_finish_date  my_score  my_status  my_rewatching  my_rewatching_ep  \
# 0            0000-00-00         9          1            NaN                 0
# ...

# %%
print(user_df.isnull().sum())
# Out:
# username                    261
# anime_id                      0
# my_watched_episodes           0
# my_start_date                 0
# my_finish_date                0
# my_score                      0
# my_status                     0
# my_rewatching          16741847
# my_rewatching_ep              0
# my_last_updated               0
# my_tags                75318950
# dtype: int64

# %%
userlist_df = pd.read_csv('data/AnimeList/UserList.csv')

# %%
userlist_df
# Out:
#                 username  user_id  user_watching  user_completed  user_onhold  \
# 0               karthiga  2255153              3              49            1
# 1       RedvelvetDaisuki  1897606             61             396           39
# 2              Damonashu    37326             45             195           27
# 3                  bskai   228342             25             414            2
# 4              shuzzable  2347781             36              72           16
# ...                  ...      ...            ...             ...          ...
# 302670      ScruffyPuffy  3119025              0              27            0
# 302671          Torasori  3975907             22             239            0
# 302672              onpc  1268417              5             169            2
# 302673            HMicca  1289601             11              73            2
# 302674        mini_kaila   236339              2              10            5
#
# ...

# %%
print(userlist_df.isnull().sum())
# Out:
# username                         1
# user_id                          0
# user_watching                    0
# user_completed                   0
# user_onhold                      0
# user_dropped                     0
# user_plantowatch                 0
# user_days_spent_watching         0
# gender                       84875
# location                    145902
# birth_date                  133926
# access_rank                 302675
# join_date                      129
# last_online                    129
# stats_mean_score               129
# stats_rewatched                129
# stats_episodes                 129
# dtype: int64
